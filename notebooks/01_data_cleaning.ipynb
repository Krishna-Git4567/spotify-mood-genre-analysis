# %% [markdown]
# # Data cleaning -
# ### [Spotify Tracks Dataset]

# %%
import pandas as pd 
# load data 
df = pd.read_csv("../data/raw/spotify-tracks-dataset-detailed.csv") 
# dimensions
df.shape  # (114000, 20)
